# %%
# MNIST analysis
import numpy as np

data = np.load('mnist.npz')

# %%
# loading the MNIST dataset

train_images = data['x_train']
train_labels = data['y_train']
test_images = data['x_test']
test_labels = data['y_test']

# %%
# The network architecture

from keras import models
from keras import layers

network = models.Sequential()
network.add(layers.Dense(512, activation='relu', input_shape=(28*28,)))
network.add(layers.Dense(10, activation='softmax'))

# %%
# the compilation step
network.compile(optimizer='rmsprop',
               loss='categorical_crossentropy',
               metrics=['accuracy'])

# %%
# prepering the image data for NN

train_images = train_images.reshape((60000, 28*28))
train_images = train_images.astype('float32')/255

test_images = test_images.reshape((10000,28*28))
test_images = test_images.astype('float32')/255

# %%
from keras.utils import to_categorical

train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# %%
# RUN
network.fit(train_images, train_labels, epochs=20, batch_size=128)
# Out:
# Epoch 1/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2091 - accuracy: 0.9395
# Epoch 2/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2013 - accuracy: 0.9421
# Epoch 3/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1936 - accuracy: 0.9448
# Epoch 4/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1866 - accuracy: 0.9463
# Epoch 5/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1795 - accuracy: 0.9489
# Epoch 6/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1728 - accuracy: 0.9506
# Epoch 7/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1668 - accuracy: 0.9525
# Epoch 8/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1609 - accuracy: 0.9543
# Epoch 9/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1550 - accuracy: 0.9558
# Epoch 10/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1495 - accuracy: 0.9575
# Epoch 11/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1448 - accuracy: 0.9593
# Epoch 12/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1398 - accuracy: 0.9604
# Epoch 13/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1357 - accuracy: 0.9613
# Epoch 14/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1311 - accuracy: 0.9627
# Epoch 15/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1271 - accuracy: 0.9640
# Epoch 16/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1231 - accuracy: 0.9651
# Epoch 17/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1193 - accuracy: 0.9666
# Epoch 18/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1160 - accuracy: 0.9668
# Epoch 19/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1123 - accuracy: 0.9683
# Epoch 20/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1090 - accuracy: 0.9692

# %%
test_loss, test_accuracy = network.evaluate(test_images, test_labels)
print("\ntest accuracy: ", test_accuracy)
print("\ntest loss: ", test_loss)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1211 - accuracy: 0.9658
#
# test accuracy:  0.9657999873161316
#
# test loss:  0.12114124745130539
